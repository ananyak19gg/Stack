# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":['maya', 'chaaya', 'savita', 'nirmala'],
    "marks":[34, 56, 87, 21],
    "city":['patna', 'jhansi', 'bhind', 'gwalior']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks     city
# 0     maya     34    patna
# 1   chaaya     56   jhansi
# 2   savita     87    bhind
# 3  nirmala     21  gwalior

# %%
df.to_csv('friends_no_index.csv',index=False)

# %%
df.head(2)
# Out:
#      name  marks    city
# 0    maya     34   patna
# 1  chaaya     56  jhansi

# %%
df.tail(3)
# Out:
#       name  marks     city
# 1   chaaya     56   jhansi
# 2   savita     87    bhind
# 3  nirmala     21  gwalior

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   49.500000
# std    28.873286
# min    21.000000
# 25%    30.750000
# 50%    45.000000
# 75%    63.750000
# max    87.000000

# %%
trains = pd.read_csv('trains.csv')

# %%
trains
# Out:
#    train no.  speed  no. of stations     city
# 0      45125    125               15    patna
# 1      79882     87               28   jhansi
# 2      89645    364               12    bhind
# 3      54621     55                8  gwalior

# %%
trains['speed']
# Out:
# 0    125
# 1     87
# 2    364
# 3     55
# Name: speed, dtype: int64

# %%
trains['speed'][0]=50
# Out:
# C:\Users\HARSHIT\AppData\Local\Temp\ipykernel_6240\317593277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trains['speed'][0]=50

# %%
trains
# Out:
#    train no.  speed  no. of stations     city
# 0      45125     50               15    patna
# 1      79882     87               28   jhansi
# 2      89645    364               12    bhind
# 3      54621     55                8  gwalior

# %%
trains.index = ['first', 'second', 'third', 'fourth']

# %%
trains
# Out:
#         train no.  speed  no. of stations     city
# first       45125     50               15    patna
# second      79882     87               28   jhansi
# third       89645    364               12    bhind
# fourth      54621     55                8  gwalior

# %%
ser = pd.Series(np.random.rand(23))

# %%
ser
# Out:
# 0     0.190060
# 1     0.068736
# 2     0.631353
# 3     0.223359
# 4     0.872586
# 5     0.758666
# 6     0.417753
# 7     0.729185
# 8     0.700882
# 9     0.110763
# 10    0.187813
# 11    0.124834
# 12    0.593791
# 13    0.560226
# 14    0.136046
# 15    0.775634
# 16    0.929424
# 17    0.901064
# 18    0.222714
# 19    0.804300
# 20    0.520518
# 21    0.424682
# 22    0.302945
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.911094  0.626737  0.197005  0.264266  0.882247
# 1    0.289635  0.355490  0.207340  0.538429  0.332459
# 2    0.967907  0.453110  0.530293  0.701117  0.865389
# 3    0.796108  0.164428  0.026913  0.936423  0.074086
# 4    0.501340  0.864506  0.600893  0.627396  0.296392
# ..        ...       ...       ...       ...       ...
# 329  0.598543  0.090856  0.274513  0.942729  0.879708
# 330  0.679484  0.355395  0.428784  0.939135  0.259736
# 331  0.617502  0.339597  0.803813  0.959372  0.712993
# 332  0.022404  0.072172  0.614140  0.116065  0.316000
# 333  0.084301  0.046891  0.934515  0.216065  0.485512
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.911094  0.626737  0.197005  0.264266  0.882247
# 1  0.289635  0.355490  0.207340  0.538429  0.332459
# 2  0.967907  0.453110  0.530293  0.701117  0.865389
# 3  0.796108  0.164428  0.026913  0.936423  0.074086
# 4  0.501340  0.864506  0.600893  0.627396  0.296392

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
#
# [334 rows x 5 columns]

# %%
newdf = newdf.drop(0, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 newdf = newdf.drop(0, axis=1)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)   5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)   5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# ...

# %%
newdf.loc[[1,2], ['C', 'D']]
# Out:
#           C         D
# 1  0.207340  0.538429
# 2  0.530293  0.701117

# %%
newdf.loc[:, ['C', 'D']]
# Out:
#             C         D
# 0    0.197005  0.264266
# 1    0.207340  0.538429
# 2    0.530293  0.701117
# 3    0.026913  0.936423
# 4    0.600893  0.627396
# ..        ...       ...
# 329  0.274513  0.942729
# 330  0.428784  0.939135
# 331  0.803813  0.959372
# 332  0.614140  0.116065
# 333  0.934515  0.216065
#
# [334 rows x 2 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 1    0.289635  0.355490  0.207340  0.538429  0.332459
# 6    0.025459  0.609575  0.155309  0.016189  0.523707
# 9    0.276112  0.166864  0.847383  0.475383  0.762113
# 10   0.173122  0.321269  0.640767  0.582969  0.058475
# 15   0.229617  0.785720  0.755926  0.685284  0.949888
# ..        ...       ...       ...       ...       ...
# 311  0.218055  0.401674  0.453056  0.713410  0.654398
# 312  0.191648  0.252806  0.240347  0.292372  0.003135
# 321  0.297928  0.129617  0.623022  0.964181  0.573651
# 332  0.022404  0.072172  0.614140  0.116065  0.316000
# 333  0.084301  0.046891  0.934515  0.216065  0.485512
#
# [85 rows x 5 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.882247204303434

# %% [markdown]
# .loc[] selects data by labels (names), while .iloc[] selects data by integer positions (numbers).

# %%
newdf.head(3)
# Out:
#             A         B         C         D         E
# 0  456.000000  0.626737  0.197005  0.264266  0.882247
# 1    0.289635  0.355490  0.207340  0.538429  0.332459
# 2    0.967907  0.453110  0.530293  0.701117  0.865389

# %%
newdf.drop(['A'], axis=1)
# Out:
#             B         C         D         E
# 0    0.626737  0.197005  0.264266  0.882247
# 1    0.355490  0.207340  0.538429  0.332459
# 2    0.453110  0.530293  0.701117  0.865389
# 3    0.164428  0.026913  0.936423  0.074086
# 4    0.864506  0.600893  0.627396  0.296392
# ..        ...       ...       ...       ...
# 329  0.090856  0.274513  0.942729  0.879708
# 330  0.355395  0.428784  0.939135  0.259736
# 331  0.339597  0.803813  0.959372  0.712993
# 332  0.072172  0.614140  0.116065  0.316000
# 333  0.046891  0.934515  0.216065  0.485512
#
# [334 rows x 4 columns]

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.289635  0.355490  0.207340  0.538429  0.332459
# 2    0.967907  0.453110  0.530293  0.701117  0.865389
# 3    0.796108  0.164428  0.026913  0.936423  0.074086
# 4    0.501340  0.864506  0.600893  0.627396  0.296392
# 5    0.907720  0.075020  0.691224  0.027379  0.360585
# ..        ...       ...       ...       ...       ...
# 329  0.598543  0.090856  0.274513  0.942729  0.879708
# 330  0.679484  0.355395  0.428784  0.939135  0.259736
# 331  0.617502  0.339597  0.803813  0.959372  0.712993
# 332  0.022404  0.072172  0.614140  0.116065  0.316000
# 333  0.084301  0.046891  0.934515  0.216065  0.485512
#
# [333 rows x 5 columns]

# %%
newdf.head()
# Out:
#             A         B         C         D         E
# 0  456.000000  0.626737  0.197005  0.264266  0.882247
# 1    0.289635  0.355490  0.207340  0.538429  0.332459
# 2    0.967907  0.453110  0.530293  0.701117  0.865389
# 3    0.796108  0.164428  0.026913  0.936423  0.074086
# 4    0.501340  0.864506  0.600893  0.627396  0.296392

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.loc[:,['B']]= None

# %%
newdf
# Out:
#               A     B         C         D         E
# 0    456.000000  None  0.197005  0.264266  0.882247
# 1      0.289635  None  0.207340  0.538429  0.332459
# 2      0.967907  None  0.530293  0.701117  0.865389
# 3      0.796108  None  0.026913  0.936423  0.074086
# 4      0.501340  None  0.600893  0.627396  0.296392
# ..          ...   ...       ...       ...       ...
# 329    0.598543  None  0.274513  0.942729  0.879708
# 330    0.679484  None  0.428784  0.939135  0.259736
# 331    0.617502  None  0.803813  0.959372  0.712993
# 332    0.022404  None  0.614140  0.116065  0.316000
# 333    0.084301  None  0.934515  0.216065  0.485512
#
# [334 rows x 5 columns]

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy" : [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT]})

# %%
df.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.4

# %%
import pandas as pd

a = [1, 7, 2]

myvar = pd.Series(a, index = ["x", "y", "z"])

print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

# %%
myvar
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# print(newdf.to_string())

# %% [markdown]
# use to_string() to print the entire DataFrame.

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
new_df = df.dropna()

# %% [markdown]
# #to change the og dataframe, use dropna(inplace = True)

# %% [markdown]
# fillna() method allows us to replace empty cells with a value

# %%
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
new_df.fillna(50, inplace = True)

# %%
print(new_df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
import pandas as pd
import numpy as np # Import numpy for NaN values

# Define the data structure
data = {
    'Duration': [60, 60, 60, 45, 45, 60, 60, 450, 30, 60, 60, 60, 60, 60, 60, 60, 60, 60, 45, 60, 45, 60, 45, 60, 45, 60, 60, 60, 60, 60, 60, 60],
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03', '2020/12/04', '2020/12/05', '2020/12/06', '2020/12/07', '2020/12/08', '2020/12/09', '2020/12/10', '2020/12/11', '2020/12/12', '2020/12/12', '2020/12/13', '2020/12/14', '2020/12/15', '2020/12/16', '2020/12/17', '2020/12/18', '2020/12/19', '2020/12/20', '2020/12/21', np.nan, '2020/12/23', '2020/12/24', '2020/12/25', 20201226, '2020/12/27', '2020/12/28', '2020/12/29', '2020/12/30', '2020/12/31'],
    'Pulse': [110, 117, 103, 109, 117, 102, 110, 104, 109, 98, 103, 100, 100, 106, 104, 98, 98, 100, 90, 103, 97, 108, 100, 130, 105, 102, 100, 92, 103, 100, 102, 92],
    'Maxpulse': [130, 145, 135, 175, 148, 127, 136, 134, 133, 124, 147, 120, 120, 128, 132, 123, 120, 120, 112, 123, 125, 131, 119, 101, 132, 126, 120, 118, 132, 132, 129, 115],
    'Calories': [409.1, 479.0, 340.0, 282.4, 406.0, 300.0, 374.0, 253.3, 195.1, 269.0, 329.3, 250.7, 250.7, 345.3, 379.3, 275.0, 215.2, 300.0, np.nan, 323.0, 243.0, 364.2, 282.0, 300.0, 246.0, 334.5, 250.0, 241.0, np.nan, 280.0, 380.3, 243.0]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Print the resulting DataFrame to display it
print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# #df['Date'] = pd.to_datetime(df['Date'], format='mixed')
#
# print(df.to_string())

# %%
print(df)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df.loc[7, 'Duration'] = 45
print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7         45  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df.loc[7, 'Duration'] = 500
print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        500  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.loc[x, "Duration"] = 120

print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        120  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
for x in df.index:
  if df.loc[x, "Duration"] > 120:
    df.drop(x, inplace = True)
print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        120  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.drop_duplicates(inplace = True)
print(df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        120  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# 17        60  2020/12/17    100       120     300.0
# ...

# %% [markdown]
# ## corr()

# %%
numeric_df = df.drop('Date', axis=1)

# Calculate and print the correlation matrix on only the numeric columns
print(numeric_df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.025286 -0.071409  0.047694
# Pulse    -0.025286  1.000000  0.269672  0.506593
# Maxpulse -0.071409  0.269672  1.000000  0.344494
# Calories  0.047694  0.506593  0.344494  1.000000

# %%
import pandas as pd
import matplotlib.pylot as plt
df.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pylot as plt
#       3 df.plot()
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %% [markdown]
# ### kind = 'scatter'

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()

# %% [markdown]
# ### kind = 'hist'

# %%
df["Duration"].plot(kind = 'hist')
